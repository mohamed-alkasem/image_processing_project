# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamed-alkasem/image_processing_project/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Yüz İfadesi Tanıma Sistemi - Hızlı Eğitim Versiyonu
# Face Expression Recognition System - Fast Training Version

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import cv2
from google.colab import drive
import time

print("=" * 60)
print("YÜZ İFADESİ TANIMA SİSTEMİ")
print("Face Expression Recognition System")
print("=" * 60)

# Mount Google Drive
print("\n[1/9] Google Drive bağlanıyor...")
drive.mount('/content/drive')

# Veri yolları
BASE_PATH = '/content/drive/MyDrive/archive'
TRAIN_PATH = os.path.join(BASE_PATH, 'train')
TEST_PATH = os.path.join(BASE_PATH, 'test')

# Hiperparametreler (HIZLI EĞİTİM için optimize edilmiş)
IMG_SIZE = 48  # Standart FER2013 boyutu
BATCH_SIZE = 128  # Daha hızlı eğitim için artırıldı
EPOCHS = 25  # Hız için azaltıldı (yeterli sonuç verir)
LEARNING_RATE = 0.002  # Daha hızlı öğrenme

print(f"\n[2/9] Hiperparametreler ayarlandı:")
print(f"  - Görüntü Boyutu: {IMG_SIZE}x{IMG_SIZE}")
print(f"  - Batch Boyutu: {BATCH_SIZE}")
print(f"  - Epoch Sayısı: {EPOCHS}")
print(f"  - Öğrenme Hızı: {LEARNING_RATE}")

# Veri yükleme fonksiyonu
def load_data_from_folder(folder_path, target_samples_per_class=1000):
    """Bir klasörden verileri yükle"""
    images = []
    labels = []
    emotion_labels = []

    print(f"\nKlasör yükleniyor: {folder_path}")

    # Tüm alt klasörleri tara
    for emotion_folder in sorted(os.listdir(folder_path)):
        emotion_path = os.path.join(folder_path, emotion_folder)

        if os.path.isdir(emotion_path):
            if emotion_folder not in emotion_labels:
                emotion_labels.append(emotion_folder)

            label_idx = emotion_labels.index(emotion_folder)

            image_files = [f for f in os.listdir(emotion_path)
                          if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

            # Her sınıftan belirli sayıda al
            image_files = image_files[:target_samples_per_class]

            loaded_count = 0
            for img_file in image_files:
                img_path = os.path.join(emotion_path, img_file)
                try:
                    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                    if img is not None:
                        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
                        images.append(img)
                        labels.append(label_idx)
                        loaded_count += 1
                except:
                    continue

            print(f"  ✓ {emotion_folder}: {loaded_count} görüntü yüklendi")

    images = np.array(images).reshape(-1, IMG_SIZE, IMG_SIZE, 1) / 255.0
    labels = np.array(labels)

    return images, labels, emotion_labels

# Eğitim ve test verilerini yükle
print(f"\n[3/9] Veriler yükleniyor...")
print("=" * 60)

# Train verisi yükle (hedef: ~5000 görüntü - HIZLI)
X_train, y_train, emotion_names = load_data_from_folder(TRAIN_PATH, target_samples_per_class=700)

# Test verisi yükle (hedef: ~1000 görüntü)
X_test, y_test, _ = load_data_from_folder(TEST_PATH, target_samples_per_class=150)

print(f"\n📊 VERİ SETİ YÜKLEME SONUÇLARI:")
print(f"  - Eğitim Seti: {len(X_train)} görüntü")
print(f"  - Test Seti: {len(X_test)} görüntü")
print(f"  - Toplam: {len(X_train) + len(X_test)} görüntü")
print(f"  - Duygu Kategorileri: {emotion_names}")

# Data Augmentation (Hafif - hız için)
train_datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.08,
    height_shift_range=0.08,
    horizontal_flip=True,
    zoom_range=0.08
)

# CNN Modeli (Optimize edilmiş mimari)
print(f"\n[4/9] Model oluşturuluyor...")

model = models.Sequential([
    # İlk Konvolüsyon Bloğu
    layers.Conv2D(32, (3, 3), activation='relu', padding='same',
                  input_shape=(IMG_SIZE, IMG_SIZE, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # İkinci Konvolüsyon Bloğu
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Üçüncü Konvolüsyon Bloğu
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Dense Katmanlar (Basitleştirilmiş)
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(len(emotion_names), activation='softmax')
])

# Model derleme
model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("\n  Model Mimarisi:")
model.summary()

# Callbacks (Hızlı durma için optimize)
callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1),
    ModelCheckpoint('best_model.h5', monitor='val_accuracy', save_best_only=True, verbose=0)
]

# Model eğitimi
print(f"\n[5/9] Model eğitimi başlıyor...")
print("=" * 60)

start_time = time.time()

history = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

training_time = time.time() - start_time
print(f"\n✓ Eğitim tamamlandı! Süre: {training_time/60:.2f} dakika")

# Model değerlendirme
print(f"\n[6/9] Model test ediliyor...")
print("=" * 60)

test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

print(f"\n📊 TEST SONUÇLARI:")
print(f"  • Test Kaybı: {test_loss:.4f}")
print(f"  • Test Doğruluğu: {test_accuracy*100:.2f}%")

# Classification Report
print(f"\n[7/9] Detaylı Performans Metrikleri:")
print("=" * 60)
print("\nSINIFLANDIRMA RAPORU:")
print(classification_report(y_test, y_pred, target_names=emotion_names, digits=4))

# Confusion Matrix
print(f"\n[8/9] Confusion Matrix oluşturuluyor...")
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=emotion_names,
            yticklabels=emotion_names,
            cbar_kws={'label': 'Görüntü Sayısı'})
plt.title('Confusion Matrix - Karışıklık Matrisi', fontsize=16, fontweight='bold')
plt.ylabel('Gerçek Duygu (Actual)', fontsize=12)
plt.xlabel('Tahmin Edilen Duygu (Predicted)', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig('confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# Eğitim grafiklerini çiz
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Doğruluk grafiği
axes[0].plot(history.history['accuracy'], label='Eğitim Doğruluğu', linewidth=2)
axes[0].plot(history.history['val_accuracy'], label='Validasyon Doğruluğu', linewidth=2)
axes[0].set_title('Model Doğruluğu', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Doğruluk (Accuracy)')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Kayıp grafiği
axes[1].plot(history.history['loss'], label='Eğitim Kaybı', linewidth=2)
axes[1].plot(history.history['val_loss'], label='Validasyon Kaybı', linewidth=2)
axes[1].set_title('Model Kaybı', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Kayıp (Loss)')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('training_history.png', dpi=300, bbox_inches='tight')
plt.show()

# Sınıf bazında doğruluk
print(f"\n[9/9] Sınıf bazında performans hesaplanıyor...")
print("\n📈 SINIF BAZINDA DOĞRULUK:")
print("=" * 60)
for i, emotion in enumerate(emotion_names):
    mask = y_test == i
    if np.sum(mask) > 0:
        class_accuracy = np.sum((y_test == i) & (y_pred == i)) / np.sum(mask)
        print(f"  {emotion:20s}: {class_accuracy*100:6.2f}%")

# Özet istatistikler
print("\n" + "=" * 60)
print("📋 ÖZET İSTATİSTİKLER")
print("=" * 60)
print(f"Toplam Veri: {len(X_train) + len(X_test)} görüntü")
print(f"Eğitim Verisi: {len(X_train)} görüntü")
print(f"Test Verisi: {len(X_test)} görüntü")
print(f"Duygu Sayısı: {len(emotion_names)}")
print(f"Eğitim Süresi: {training_time/60:.2f} dakika")
print(f"En İyi Doğruluk: {max(history.history['val_accuracy'])*100:.2f}%")
print(f"Final Test Doğruluğu: {test_accuracy*100:.2f}%")
print("=" * 60)

# Model kaydetme
model.save('yuz_ifadesi_model_final.h5')
print("\n✅ Model 'yuz_ifadesi_model_final.h5' olarak kaydedildi!")
print("✅ Confusion Matrix 'confusion_matrix.png' olarak kaydedildi!")
print("✅ Eğitim grafikleri 'training_history.png' olarak kaydedildi!")
print("\n🎉 İşlem başarıyla tamamlandı!")
# Out:
# ============================================================
# YÜZ İFADESİ TANIMA SİSTEMİ
# Face Expression Recognition System
# ============================================================
#
# [1/9] Google Drive bağlanıyor...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# [2/9] Hiperparametreler ayarlandı:
#   - Görüntü Boyutu: 48x48
#   - Batch Boyutu: 128
#   - Epoch Sayısı: 25
#   - Öğrenme Hızı: 0.002
#
# [3/9] Veriler yükleniyor...
# ============================================================
#
# Klasör yükleniyor: /content/drive/MyDrive/archive/train
#   ✓ angry: 700 görüntü yüklendi
#   ✓ disgust: 436 görüntü yüklendi
#   ✓ fear: 700 görüntü yüklendi
#   ✓ happy: 700 görüntü yüklendi
#   ✓ neutral: 700 görüntü yüklendi
#   ✓ sad: 700 görüntü yüklendi
#   ✓ surprise: 700 görüntü yüklendi
#
# Klasör yükleniyor: /content/drive/MyDrive/archive/test
#   ✓ angry: 150 görüntü yüklendi
#   ✓ disgust: 111 görüntü yüklendi
#   ✓ fear: 150 görüntü yüklendi
#   ✓ happy: 150 görüntü yüklendi
#   ✓ neutral: 150 görüntü yüklendi
#   ✓ sad: 150 görüntü yüklendi
#   ✓ surprise: 150 görüntü yüklendi
#
# 📊 VERİ SETİ YÜKLEME SONUÇLARI:
#   - Eğitim Seti: 4636 görüntü
#   - Test Seti: 1011 görüntü
#   - Toplam: 5647 görüntü
#   - Duygu Kategorileri: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
#
# [4/9] Model oluşturuluyor...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#   Model Mimarisi:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,275,271 (4.86 MB)
#  Trainable params: 1,274,823 (4.86 MB)
#  Non-trainable params: 448 (1.75 KB)
# [5/9] Model eğitimi başlıyor...
# ============================================================
# Epoch 1/25
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.1483 - loss: 4.4817
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 21s 340ms/step - accuracy: 0.1483 - loss: 4.4405 - val_accuracy: 0.1583 - val_loss: 3.3007 - learning_rate: 0.0020
# Epoch 2/25
# 36/37 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.1699 - loss: 1.9483
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.1696 - loss: 1.9482 - val_accuracy: 0.1622 - val_loss: 4.3015 - learning_rate: 0.0020
# Epoch 3/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.1478 - loss: 1.9387 - val_accuracy: 0.1583 - val_loss: 2.8973 - learning_rate: 0.0020
# Epoch 4/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.1704 - loss: 1.9322 - val_accuracy: 0.1355 - val_loss: 2.2456 - learning_rate: 0.0020
# Epoch 5/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.1692 - loss: 1.9297 - val_accuracy: 0.1385 - val_loss: 2.0315 - learning_rate: 0.0020
# Epoch 6/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2055 - loss: 1.9130
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.2051 - loss: 1.9130 - val_accuracy: 0.1662 - val_loss: 1.9768 - learning_rate: 0.0020
# Epoch 7/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.1857 - loss: 1.9086 - val_accuracy: 0.1494 - val_loss: 1.9586 - learning_rate: 0.0020
# Epoch 8/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.1833 - loss: 1.9026 - val_accuracy: 0.1503 - val_loss: 1.9638 - learning_rate: 0.0020
# Epoch 9/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.1964 - loss: 1.8935 - val_accuracy: 0.1652 - val_loss: 1.9410 - learning_rate: 0.0020
# Epoch 10/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.1961 - loss: 1.9001 - val_accuracy: 0.1573 - val_loss: 1.9421 - learning_rate: 0.0020
# Epoch 11/25
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.1967 - loss: 1.8950 - val_accuracy: 0.1642 - val_loss: 1.9465 - learning_rate: 0.0020
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
#
# ✓ Eğitim tamamlandı! Süre: 0.82 dakika
#
# [6/9] Model test ediliyor...
# ============================================================
#
# 📊 TEST SONUÇLARI:
#   • Test Kaybı: 1.9768
#   • Test Doğruluğu: 16.62%
#
# [7/9] Detaylı Performans Metrikleri:
# ============================================================
#
# SINIFLANDIRMA RAPORU:
#               precision    recall  f1-score   support
#
#        angry     0.0952    0.0133    0.0234       150
#      disgust     0.0000    0.0000    0.0000       111
#         fear     0.0000    0.0000    0.0000       150
#        happy     0.1583    0.2533    0.1949       150
#      neutral     0.0000    0.0000    0.0000       150
#          sad     0.1720    0.8533    0.2864       150
#     surprise     0.0000    0.0000    0.0000       150
#
#     accuracy                         0.1662      1011
#    macro avg     0.0608    0.1600    0.0721      1011
# weighted avg     0.0631    0.1662    0.0749      1011
#
#
# [8/9] Confusion Matrix oluşturuluyor...
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# [9/9] Sınıf bazında performans hesaplanıyor...
#
# 📈 SINIF BAZINDA DOĞRULUK:
# ============================================================
#   angry               :   1.33%
#   disgust             :   0.00%
#   fear                :   0.00%
#   happy               :  25.33%
#   neutral             :   0.00%
#   sad                 :  85.33%
#   surprise            :   0.00%
#
# ============================================================
# 📋 ÖZET İSTATİSTİKLER
# ============================================================
# Toplam Veri: 5647 görüntü
# Eğitim Verisi: 4636 görüntü
# Test Verisi: 1011 görüntü
# Duygu Sayısı: 7
# Eğitim Süresi: 0.82 dakika
# En İyi Doğruluk: 16.62%
# Final Test Doğruluğu: 16.62%
# ============================================================
#
# ✅ Model 'yuz_ifadesi_model_final.h5' olarak kaydedildi!
# ✅ Confusion Matrix 'confusion_matrix.png' olarak kaydedildi!
# ✅ Eğitim grafikleri 'training_history.png' olarak kaydedildi!
#
# 🎉 İşlem başarıyla tamamlandı!
